# %%
# %reload_ext sql

# %%
# %sql postgresql://appdev@data/appdev
# Out:
# 'Connected: appdev@appdev'

# %% [markdown]
# # Materialized Joins

# %% [markdown]
# #### 1. On the table "circuits" report:

# %%
# %sql SELECT * FROM circuits LIMIT 10;
# Out:
# 10 rows affected.
# [(1, 'albert_park', 'Albert Park Grand Prix Circuit', 'Melbourne', 'Australia', -37.8497, 144.968, 10, 'http://en.wikipedia.org/wiki/Melbourne_Grand_Prix_Circuit', '(144.968,-37.8497)'),
#  (2, 'sepang', 'Sepang International Circuit', 'Kuala Lumpur', 'Malaysia', 2.76083, 101.738, None, 'http://en.wikipedia.org/wiki/Sepang_International_Circuit', '(101.738,2.76083)'),
#  (3, 'bahrain', 'Bahrain International Circuit', 'Sakhir', 'Bahrain', 26.0325, 50.5106, None, 'http://en.wikipedia.org/wiki/Bahrain_International_Circuit', '(50.5106,26.0325)'),
#  (4, 'catalunya', 'Circuit de Barcelona-Catalunya', 'Montmeló', 'Spain', 41.57, 2.26111, None, 'http://en.wikipedia.org/wiki/Circuit_de_Barcelona-Catalunya', '(2.26111,41.57)'),
#  (5, 'istanbul', 'Istanbul Park', 'Istanbul', 'Turkey', 40.9517, 29.405, None, 'http://en.wikipedia.org/wiki/Istanbul_Park', '(29.405,40.9517)'),
#  (6, 'monaco', 'Circuit de Monaco', 'Monte-Carlo', 'Monaco', 43.7347, 7.42056, None, 'http://en.wikipedia.org/wiki/Circuit_de_Monaco', '(7.42056,43.7347)'),
#  (7, 'villeneuve', 'Circuit Gilles Villeneuve', 'Montreal', 'Canada', 45.5, -73.5228, None, 'http://en.wikipedia.org/wiki/Circuit_Gilles_Villeneuve', '(-73.5228,45.5)'),
#  (8, 'magny_cours', 'Circuit de Nevers Magny-Cours', 'Magny Cours', 'France', 46.8642, 3.16361, None, 'http://en.wikipedia.org/wiki/Circuit_de_Nevers_Magny-Cours', '(3.16361,46.8642)'),
#  (9, 'silverstone', 'Silverstone Circuit', 'Silverstone', 'UK', 52.0786, -1.01694, None, 'http://en.wikipedia.org/wiki/Silverstone_Circuit', '(-1.01694,52.0786)'),
#  (10, 'hockenheimring', 'Hockenheimring', 'Hockenheim', 'Germany', 49.3278, 8.56583, None, 'http://en.wikipedia.org/wiki/Hockenheimring', '(8.56583,49.3278)')]

# %%
# %sql select * from pg_indexes where tablename = 'circuits';
# Out:
# 3 rows affected.
# [('f1db', 'circuits', 'idx_17102_url', None, 'CREATE UNIQUE INDEX idx_17102_url ON circuits USING btree (url)'),
#  ('f1db', 'circuits', 'circuits_position_idx', None, 'CREATE INDEX circuits_position_idx ON circuits USING gist ("position")'),
#  ('f1db', 'circuits', 'idx_17102_primary', None, 'CREATE UNIQUE INDEX idx_17102_primary ON circuits USING btree (circuitid)')]

# %% [markdown]
# - What type of indices exists for the table and why they are of that type (and not some other type)
#
#
# idx_17102_url index is of btree (url)
#
# BTREE is the default index type for most storage engines. The general idea of a B-Tree is that all the values are stored in order, and each leaf page is the same distance from the root. B Tree index speeds up the data access because storage engine don't have to scan the whole table instead it will start from root node.
#
# circuits_position_idx index is of gist ("position")
#
# GIST allows to generalise the search structures, so we can build indexes on type we choose. In this case GIST index is with <key, pointer> pairs using position instead of integers (like in B-trees).
#
# idx_17102_primary index is of btree (circuitid)
#
# In this case index is of BTREE on circuitid column.
#
# - The amount of space each index takes up

# %%
# %sql select pg_size_pretty(pg_relation_size('idx_17102_url'));
# Out:
# 1 rows affected.
# [('16 kB',)]

# %%
# %sql select pg_size_pretty(pg_relation_size('circuits_position_idx'));
# Out:
# 1 rows affected.
# [('8192 bytes',)]

# %%
# %sql select pg_size_pretty(pg_relation_size('idx_17102_primary'));
# Out:
# 1 rows affected.
# [('16 kB',)]

# %% [markdown]
# # The winner of all the races, but only if they are younger than 38 years.

# %%
# %sql SELECT * FROM information_schema.tables WHERE table_schema = 'f1db';
# Out:
# 13 rows affected.
# [('appdev', 'f1db', 'circuits', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'constructorresults', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'constructors', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'constructorstandings', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'drivers', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'driverstandings', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'laptimes', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'pitstops', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'qualifying', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'races', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'results', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'seasons', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'status', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)]

# %%
# %%sql
# SELECT races.date as "Race Date",
# drivers.surname as "Driver's Surname",
# date_part('year', age('2018-03-19',dob)) as "Driver's Age",
# races.time as "Track Time(ms)",
# races.name as "Name",
# circuits.name as "Circuit Name"
# FROM results
# JOIN drivers USING (driverid)
# JOIN races USING (raceId)
# JOIN circuits USING (circuitid)
# WHERE results.rank = 1
# AND date_part('year', age('2018-03-19',dob)) < 38;
# Out:
# 154 rows affected.
# [(datetime.date(2008, 3, 16), 'Kovalainen', 36.0, datetime.time(4, 30), 'Australian Grand Prix', 'Albert Park Grand Prix Circuit'),
#  (datetime.date(2008, 4, 6), 'Kovalainen', 36.0, datetime.time(11, 30), 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2008, 8, 24), 'Massa', 36.0, datetime.time(12, 0), 'European Grand Prix', 'Valencia Street Circuit'),
#  (datetime.date(2008, 10, 12), 'Massa', 36.0, datetime.time(4, 30), 'Japanese Grand Prix', 'Fuji Speedway'),
#  (datetime.date(2008, 10, 19), 'Hamilton', 33.0, datetime.time(7, 0), 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2008, 11, 2), 'Massa', 36.0, datetime.time(17, 0), 'Brazilian Grand Prix', 'Autódromo José Carlos Pace'),
#  (datetime.date(2007, 4, 8), 'Hamilton', 33.0, datetime.time(7, 0), 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2007, 4, 15), 'Massa', 36.0, datetime.time(11, 30), 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2007, 5, 13), 'Massa', 36.0, datetime.time(12, 0), 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2007, 5, 27), 'Alonso', 36.0, datetime.time(12, 0), 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2007, 6, 10), 'Alonso', 36.0, datetime.time(17, 0), 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2007, 7, 1), 'Massa', 36.0, datetime.time(12, 0), 'French Grand Prix', 'Circuit de Nevers Magny-Cours'),
#  (datetime.date(2007, 7, 22), 'Massa', 36.0, datetime.time(12, 0), 'European Grand Prix', 'Nürburgring'),
#  (datetime.date(2007, 9, 9), 'Alonso', 36.0, datetime.time(12, 0), 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2007, 9, 16), 'Massa', 36.0, datetime.time(12, 0), 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2007, 9, 30), 'Hamilton', 33.0, datetime.time(4, 30), 'Japanese Grand Prix', 'Fuji Speedway'),
#  (datetime.date(2007, 10, 7), 'Massa', 36.0, datetime.time(6, 0), 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2006, 3, 12), 'Rosberg', 32.0, datetime.time(14, 30), 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2006, 3, 19), 'Alonso', 36.0, datetime.time(15, 0), 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2006, 4, 23), 'Alonso', 36.0, datetime.time(14, 0), 'San Marino Grand Prix', 'Autodromo Enzo e Dino Ferrari'),
#  (datetime.date(2006, 5, 14), 'Massa', 36.0, datetime.time(14, 0), 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2006, 6, 11), 'Alonso', 36.0, datetime.time(12, 0), 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2006, 8, 6), 'Massa', 36.0, datetime.time(14, 0), 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2006, 10, 1), 'Alonso', 36.0, datetime.time(14, 0), 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2006, 10, 8), 'Alonso', 36.0, datetime.time(14, 0), 'Japanese Grand Prix', 'Suzuka Circuit'),
#  (datetime.date(2005, 3, 6), 'Alonso', 36.0, datetime.time(14, 0), 'Australian Grand Prix', 'Albert Park Grand Prix Circuit'),
#  (datetime.date(2005, 5, 29), 'Alonso', 36.0, datetime.time(14, 0), 'European Grand Prix', 'Nürburgring'),
#  (datetime.date(2009, 3, 29), 'Rosberg', 32.0, datetime.time(6, 0), 'Australian Grand Prix', 'Albert Park Grand Prix Circuit'),
#  (datetime.date(2009, 5, 24), 'Massa', 36.0, datetime.time(12, 0), 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2009, 6, 21), 'Vettel', 30.0, datetime.time(12, 0), 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2009, 7, 12), 'Alonso', 36.0, datetime.time(12, 0), 'German Grand Prix', 'Nürburgring'),
#  (datetime.date(2009, 8, 23), 'Glock', 36.0, datetime.time(12, 0), 'European Grand Prix', 'Valencia Street Circuit'),
#  (datetime.date(2009, 8, 30), 'Vettel', 30.0, datetime.time(12, 0), 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2009, 9, 13), 'Sutil', 35.0, datetime.time(12, 0), 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2009, 9, 27), 'Alonso', 36.0, datetime.time(12, 0), 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2009, 11, 1), 'Vettel', 30.0, datetime.time(11, 0), 'Abu Dhabi Grand Prix', 'Yas Marina Circuit'),
#  (datetime.date(2010, 3, 14), 'Alonso', 36.0, datetime.time(12, 0), 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2010, 4, 18), 'Hamilton', 33.0, datetime.time(6, 0), 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2010, 5, 9), 'Hamilton', 33.0, datetime.time(12, 0), 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2010, 5, 16), 'Vettel', 30.0, datetime.time(12, 0), 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2010, 5, 30), 'Petrov', 33.0, datetime.time(11, 0), 'Turkish Grand Prix', 'Istanbul Park'),
#  (datetime.date(2010, 6, 13), 'Kubica', 33.0, datetime.time(16, 0), 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2010, 7, 11), 'Alonso', 36.0, datetime.time(12, 0), 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2010, 7, 25), 'Vettel', 30.0, datetime.time(12, 0), 'German Grand Prix', 'Hockenheimring'),
#  (datetime.date(2010, 8, 1), 'Vettel', 30.0, datetime.time(12, 0), 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2010, 8, 29), 'Hamilton', 33.0, datetime.time(12, 0), 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2010, 9, 12), 'Alonso', 36.0, datetime.time(12, 0), 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2010, 9, 26), 'Alonso', 36.0, datetime.time(12, 0), 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2010, 10, 24), 'Alonso', 36.0, datetime.time(5, 0), 'Korean Grand Prix', 'Korean International Circuit'),
#  (datetime.date(2010, 11, 7), 'Hamilton', 33.0, datetime.time(16, 0), 'Brazilian Grand Prix', 'Autódromo José Carlos Pace'),
#  (datetime.date(2010, 11, 14), 'Hamilton', 33.0, datetime.time(13, 0), 'Abu Dhabi Grand Prix', 'Yas Marina Circuit'),
#  (datetime.date(2011, 3, 27), 'Massa', 36.0, datetime.time(6, 0), 'Australian Grand Prix', 'Albert Park Grand Prix Circuit'),
#  (datetime.date(2011, 5, 22), 'Hamilton', 33.0, datetime.time(12, 0), 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2011, 6, 26), 'Vettel', 30.0, datetime.time(12, 0), 'European Grand Prix', 'Valencia Street Circuit'),
#  (datetime.date(2011, 7, 10), 'Alonso', 36.0, datetime.time(12, 0), 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2011, 7, 24), 'Hamilton', 33.0, datetime.time(12, 0), 'German Grand Prix', 'Nürburgring'),
#  (datetime.date(2011, 7, 31), 'Massa', 36.0, datetime.time(12, 0), 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2011, 9, 11), 'Hamilton', 33.0, datetime.time(12, 0), 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2011, 10, 16), 'Vettel', 30.0, datetime.time(6, 0), 'Korean Grand Prix', 'Korean International Circuit'),
#  (datetime.date(2011, 10, 30), 'Vettel', 30.0, datetime.time(9, 30), 'Indian Grand Prix', 'Buddh International Circuit'),
#  (datetime.date(2012, 4, 15), 'Kobayashi', 31.0, datetime.time(7, 0), 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2012, 4, 22), 'Vettel', 30.0, datetime.time(12, 0), 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2012, 5, 13), 'Grosjean', 31.0, datetime.time(12, 0), 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2012, 5, 27), 'Pérez', 28.0, datetime.time(12, 0), 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2012, 6, 10), 'Vettel', 30.0, datetime.time(18, 0), 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2012, 6, 24), 'Rosberg', 32.0, datetime.time(12, 0), 'European Grand Prix', 'Valencia Street Circuit'),
#  (datetime.date(2012, 7, 29), 'Vettel', 30.0, datetime.time(12, 0), 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2012, 9, 2), 'Senna', 34.0, datetime.time(12, 0), 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2012, 9, 9), 'Rosberg', 32.0, datetime.time(12, 0), 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2012, 9, 23), 'Hülkenberg', 30.0, datetime.time(12, 0), 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2012, 10, 7), 'Vettel', 30.0, datetime.time(6, 0), 'Japanese Grand Prix', 'Suzuka Circuit'),
#  (datetime.date(2012, 11, 4), 'Vettel', 30.0, datetime.time(13, 0), 'Abu Dhabi Grand Prix', 'Yas Marina Circuit'),
#  (datetime.date(2012, 11, 18), 'Vettel', 30.0, datetime.time(19, 0), 'United States Grand Prix', 'Circuit of the Americas'),
#  (datetime.date(2012, 11, 25), 'Hamilton', 33.0, datetime.time(16, 0), 'Brazilian Grand Prix', 'Autódromo José Carlos Pace'),
#  (datetime.date(2013, 3, 24), 'Pérez', 28.0, datetime.time(8, 0), 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2013, 4, 14), 'Vettel', 30.0, datetime.time(7, 0), 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2013, 4, 21), 'Vettel', 30.0, datetime.time(12, 0), 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2013, 5, 12), 'Gutiérrez', 26.0, datetime.time(12, 0), 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2013, 5, 26), 'Vettel', 30.0, datetime.time(12, 0), 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2013, 7, 7), 'Alonso', 36.0, datetime.time(12, 0), 'German Grand Prix', 'Nürburgring'),
#  (datetime.date(2013, 8, 25), 'Vettel', 30.0, datetime.time(12, 0), 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2013, 9, 8), 'Hamilton', 33.0, datetime.time(12, 0), 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2013, 9, 22), 'Vettel', 30.0, datetime.time(12, 0), 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2013, 10, 6), 'Vettel', 30.0, datetime.time(6, 0), 'Korean Grand Prix', 'Korean International Circuit'),
#  (datetime.date(2013, 11, 3), 'Alonso', 36.0, datetime.time(13, 0), 'Abu Dhabi Grand Prix', 'Yas Marina Circuit'),
#  (datetime.date(2013, 11, 17), 'Vettel', 30.0, datetime.time(19, 0), 'United States Grand Prix', 'Circuit of the Americas'),
#  (datetime.date(2014, 3, 16), 'Rosberg', 32.0, datetime.time(6, 0), 'Australian Grand Prix', 'Albert Park Grand Prix Circuit'),
#  (datetime.date(2014, 3, 30), 'Hamilton', 33.0, datetime.time(8, 0), 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2014, 4, 6), 'Rosberg', 32.0, datetime.time(15, 0), 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2014, 4, 20), 'Rosberg', 32.0, datetime.time(7, 0), 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2014, 5, 11), 'Vettel', 30.0, datetime.time(12, 0), 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2014, 6, 8), 'Massa', 36.0, datetime.time(18, 0), 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2014, 6, 22), 'Pérez', 28.0, datetime.time(12, 0), 'Austrian Grand Prix', 'Red Bull Ring'),
#  (datetime.date(2014, 7, 6), 'Hamilton', 33.0, datetime.time(12, 0), 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2014, 7, 20), 'Hamilton', 33.0, datetime.time(12, 0), 'German Grand Prix', 'Hockenheimring'),
#  (datetime.date(2014, 7, 27), 'Rosberg', 32.0, datetime.time(12, 0), 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2014, 8, 24), 'Rosberg', 32.0, datetime.time(12, 0), 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2014, 9, 7), 'Hamilton', 33.0, datetime.time(12, 0), 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2014, 9, 21), 'Hamilton', 33.0, datetime.time(12, 0), 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2014, 10, 5), 'Hamilton', 33.0, datetime.time(6, 0), 'Japanese Grand Prix', 'Suzuka Circuit'),
#  (datetime.date(2014, 10, 12), 'Bottas', 28.0, datetime.time(11, 0), 'Russian Grand Prix', 'Sochi Autodrom'),
#  (datetime.date(2014, 11, 2), 'Vettel', 30.0, datetime.time(20, 0), 'United States Grand Prix', 'Circuit of the Americas'),
#  (datetime.date(2014, 11, 9), 'Hamilton', 33.0, datetime.time(16, 0), 'Brazilian Grand Prix', 'Autódromo José Carlos Pace'),
#  (datetime.date(2014, 11, 23), 'Ricciardo', 28.0, datetime.time(13, 0), 'Abu Dhabi Grand Prix', 'Yas Marina Circuit'),
#  (datetime.date(2015, 3, 15), 'Hamilton', 33.0, datetime.time(5, 0), 'Australian Grand Prix', 'Albert Park Grand Prix Circuit'),
#  (datetime.date(2015, 3, 29), 'Rosberg', 32.0, datetime.time(7, 0), 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2015, 4, 12), 'Hamilton', 33.0, datetime.time(6, 0), 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2015, 5, 10), 'Hamilton', 33.0, datetime.time(12, 0), 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2015, 5, 24), 'Ricciardo', 28.0, datetime.time(12, 0), 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2015, 6, 21), 'Rosberg', 32.0, datetime.time(12, 0), 'Austrian Grand Prix', 'Red Bull Ring'),
#  (datetime.date(2015, 7, 5), 'Hamilton', 33.0, datetime.time(12, 0), 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2015, 7, 26), 'Ricciardo', 28.0, datetime.time(12, 0), 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2015, 8, 23), 'Rosberg', 32.0, datetime.time(12, 0), 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2015, 9, 6), 'Hamilton', 33.0, datetime.time(12, 0), 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2015, 9, 20), 'Ricciardo', 28.0, datetime.time(12, 0), 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2015, 9, 27), 'Hamilton', 33.0, datetime.time(5, 0), 'Japanese Grand Prix', 'Suzuka Circuit'),
#  (datetime.date(2015, 10, 11), 'Vettel', 30.0, datetime.time(11, 0), 'Russian Grand Prix', 'Sochi Autodrom'),
#  (datetime.date(2015, 10, 25), 'Rosberg', 32.0, datetime.time(19, 0), 'United States Grand Prix', 'Circuit of the Americas'),
#  (datetime.date(2015, 11, 1), 'Rosberg', 32.0, datetime.time(19, 0), 'Mexican Grand Prix', 'Autódromo Hermanos Rodríguez'),
#  (datetime.date(2015, 11, 15), 'Hamilton', 33.0, datetime.time(16, 0), 'Brazilian Grand Prix', 'Autódromo José Carlos Pace'),
#  (datetime.date(2015, 11, 29), 'Hamilton', 33.0, datetime.time(13, 0), 'Abu Dhabi Grand Prix', 'Yas Marina Circuit'),
#  (datetime.date(2016, 3, 20), 'Ricciardo', 28.0, datetime.time(5, 0), 'Australian Grand Prix', 'Albert Park Grand Prix Circuit'),
#  (datetime.date(2016, 4, 3), 'Rosberg', 32.0, datetime.time(15, 0), 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2016, 4, 17), 'Hülkenberg', 30.0, datetime.time(6, 0), 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2016, 5, 1), 'Rosberg', 32.0, datetime.time(12, 0), 'Russian Grand Prix', 'Sochi Autodrom'),
#  (datetime.date(2016, 5, 15), 'Kvyat', 23.0, datetime.time(12, 0), 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2016, 5, 29), 'Hamilton', 33.0, datetime.time(12, 0), 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2016, 6, 12), 'Rosberg', 32.0, datetime.time(18, 0), 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2016, 6, 19), 'Rosberg', 32.0, datetime.time(13, 0), 'European Grand Prix', 'Baku City Circuit'),
#  (datetime.date(2016, 7, 3), 'Hamilton', 33.0, datetime.time(12, 0), 'Austrian Grand Prix', 'Red Bull Ring'),
#  (datetime.date(2016, 7, 10), 'Rosberg', 32.0, datetime.time(12, 0), 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2016, 7, 31), 'Ricciardo', 28.0, datetime.time(12, 0), 'German Grand Prix', 'Hockenheimring'),
#  (datetime.date(2016, 8, 28), 'Hamilton', 33.0, datetime.time(12, 0), 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2016, 9, 4), 'Alonso', 36.0, datetime.time(12, 0), 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2016, 9, 18), 'Ricciardo', 28.0, datetime.time(12, 0), 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2016, 10, 2), 'Rosberg', 32.0, datetime.time(7, 0), 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2016, 10, 9), 'Vettel', 30.0, datetime.time(5, 0), 'Japanese Grand Prix', 'Suzuka Circuit'),
#  (datetime.date(2016, 10, 23), 'Vettel', 30.0, datetime.time(19, 0), 'United States Grand Prix', 'Circuit of the Americas'),
#  (datetime.date(2016, 10, 30), 'Ricciardo', 28.0, datetime.time(19, 0), 'Mexican Grand Prix', 'Autódromo Hermanos Rodríguez'),
#  (datetime.date(2016, 11, 13), 'Verstappen', 20.0, datetime.time(16, 0), 'Brazilian Grand Prix', 'Autódromo José Carlos Pace'),
#  (datetime.date(2016, 11, 27), 'Vettel', 30.0, datetime.time(13, 0), 'Abu Dhabi Grand Prix', 'Yas Marina Circuit'),
#  (datetime.date(2017, 4, 9), 'Hamilton', 33.0, datetime.time(6, 0), 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2017, 4, 16), 'Hamilton', 33.0, datetime.time(15, 0), 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2017, 5, 14), 'Hamilton', 33.0, datetime.time(12, 0), 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2017, 5, 28), 'Pérez', 28.0, datetime.time(12, 0), 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2017, 6, 11), 'Hamilton', 33.0, datetime.time(18, 0), 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2017, 6, 25), 'Vettel', 30.0, datetime.time(13, 0), 'Azerbaijan Grand Prix', 'Baku City Circuit'),
#  (datetime.date(2017, 7, 9), 'Hamilton', 33.0, datetime.time(12, 0), 'Austrian Grand Prix', 'Red Bull Ring'),
#  (datetime.date(2017, 7, 16), 'Hamilton', 33.0, datetime.time(12, 0), 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2017, 7, 30), 'Alonso', 36.0, datetime.time(12, 0), 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2017, 8, 27), 'Vettel', 30.0, datetime.time(12, 0), 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2017, 9, 3), 'Ricciardo', 28.0, datetime.time(12, 0), 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2017, 9, 17), 'Hamilton', 33.0, datetime.time(12, 0), 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2017, 10, 1), 'Vettel', 30.0, datetime.time(7, 0), 'Malaysian Grand Prix', 'Sepang International Circuit')]

# %% [markdown]
# # Describe the query using ``EXPLAIN ANALYZE``

# %%
# %%sql EXPLAIN ANALYZE
# SELECT races.date as "Race Date",
# drivers.surname as "Driver's Surname",
# date_part('year', age('2018-03-19',dob)) as "Driver's Age",
# races.time as "Track Time(ms)",
# races.name as "Name", circuits.name as "Circuit Name"
# FROM results
# JOIN drivers USING (driverid)
# JOIN races USING (raceId)
# JOIN circuits USING (circuitid)
# WHERE results.rank = 1
# AND date_part('year', age('2018-03-19',dob)) < 38;
# Out:
# 22 rows affected.
# [('Hash Join  (cost=77.92..792.94 rows=86 width=66) (actual time=0.871..4.711 rows=154 loops=1)',),
#  ('  Hash Cond: (races.circuitid = circuits.circuitid)',),
#  ('  ->  Hash Join  (cost=74.28..787.57 rows=86 width=50) (actual time=0.814..4.539 rows=154 loops=1)',),
#  ('        Hash Cond: (results.raceid = races.raceid)',),
#  ('        ->  Hash Join  (cost=34.32..746.53 rows=86 width=19) (actual time=0.431..4.093 rows=154 loops=1)',),
#  ('              Hash Cond: (results.driverid = drivers.driverid)',),
#  ('              ->  Seq Scan on results  (cost=0.00..708.96 rows=257 width=16) (actual time=0.008..3.612 rows=257 loops=1)',),
#  ('                    Filter: (rank = 1)',),
#  ('                    Rows Removed by Filter: 23420',),
#  ('              ->  Hash  (cost=30.82..30.82 rows=280 width=19) (actual time=0.410..0.410 rows=60 loops=1)',),
#  ('                    Buckets: 1024  Batches: 1  Memory Usage: 12kB',),
#  ('                    ->  Seq Scan on drivers  (cost=0.00..30.82 rows=280 width=19) (actual time=0.013..0.398 rows=60 loops=1)',),
#  ("                          Filter: (date_part('year'::text, age('2018-03-19 00:00:00+00'::timestamp with time zone, (dob)::timestamp with time zone)) < '38'::double precision)",),
#  ('                          Rows Removed by Filter: 781',),
#  ('        ->  Hash  (cost=27.76..27.76 rows=976 width=47) (actual time=0.374..0.374 rows=976 loops=1)',),
#  ('              Buckets: 1024  Batches: 1  Memory Usage: 83kB',),
#  ('              ->  Seq Scan on races  (cost=0.00..27.76 rows=976 width=47) (actual time=0.006..0.205 rows=976 loops=1)',),
#  ('  ->  Hash  (cost=2.73..2.73 rows=73 width=28) (actual time=0.045..0.045 rows=73 loops=1)',),
#  ('        Buckets: 1024  Batches: 1  Memory Usage: 13kB',),
#  ('        ->  Seq Scan on circuits  (cost=0.00..2.73 rows=73 width=28) (actual time=0.010..0.023 rows=73 loops=1)',),
#  ('Planning time: 0.406 ms',),
#  ('Execution time: 4.794 ms',)]

# %% [markdown]
# EXPLAIN ANALYZE gives us detailed information about the query plan. It displays the actions executed with the arrows pointing to the information of the action "->". The information display is the actual time, rows and the loops it went through. The actions also include the number of Buckets, Batches and memory being used.
#
#     How many calls are you making?
#     There are 10 actions taken on this query.
#
#     How long does it take to perform the query?
#     It took 5.428 ms to perform the query.

# %% [markdown]
# # Create a materialized view of your query.

# %%
# %%sql CREATE VIEW winners AS
# SELECT races.date as "Race Date",
# drivers.surname as "Driver's Surname",
# date_part('year', age('2018-03-19',dob)) as "Driver's Age",
# races.time as "Track Time(ms)",
# races.name as "Name",
# circuits.name as "Circuit Name"
# FROM results
# JOIN drivers USING (driverid)
# JOIN races USING (raceId)
# JOIN circuits USING (circuitid)
# WHERE results.rank = 1
# AND date_part('year', age('2018-03-19',dob)) < 38;
# Out:
# (psycopg2.ProgrammingError) relation "winners" already exists
#  [SQL: 'CREATE VIEW winners AS\nSELECT races.date as "Race Date", \ndrivers.surname as "Driver\'s Surname", \ndate_part(\'year\', age(\'2018-03-19\',dob)) as "Driver\'s Age", \nraces.time as "Track Time(ms)", \nraces.name as "Name", \ncircuits.name as "Circuit Name" \nFROM results\nJOIN drivers USING (driverid)\nJOIN races USING (raceId)\nJOIN circuits USING (circuitid)\nWHERE results.rank = 1\nAND date_part(\'year\', age(\'2018-03-19\',dob)) < 38;']

# %%
# %sql EXPLAIN ANALYZE SELECT * FROM winners;
# Out:
# 22 rows affected.
# [('Hash Join  (cost=77.92..792.94 rows=86 width=66) (actual time=1.090..5.808 rows=154 loops=1)',),
#  ('  Hash Cond: (races.circuitid = circuits.circuitid)',),
#  ('  ->  Hash Join  (cost=74.28..787.57 rows=86 width=50) (actual time=1.041..5.653 rows=154 loops=1)',),
#  ('        Hash Cond: (results.raceid = races.raceid)',),
#  ('        ->  Hash Join  (cost=34.32..746.53 rows=86 width=19) (actual time=0.567..5.130 rows=154 loops=1)',),
#  ('              Hash Cond: (results.driverid = drivers.driverid)',),
#  ('              ->  Seq Scan on results  (cost=0.00..708.96 rows=257 width=16) (actual time=0.009..4.500 rows=257 loops=1)',),
#  ('                    Filter: (rank = 1)',),
#  ('                    Rows Removed by Filter: 23420',),
#  ('              ->  Hash  (cost=30.82..30.82 rows=280 width=19) (actual time=0.549..0.549 rows=60 loops=1)',),
#  ('                    Buckets: 1024  Batches: 1  Memory Usage: 12kB',),
#  ('                    ->  Seq Scan on drivers  (cost=0.00..30.82 rows=280 width=19) (actual time=0.012..0.532 rows=60 loops=1)',),
#  ("                          Filter: (date_part('year'::text, age('2018-03-19 00:00:00+00'::timestamp with time zone, (dob)::timestamp with time zone)) < '38'::double precision)",),
#  ('                          Rows Removed by Filter: 781',),
#  ('        ->  Hash  (cost=27.76..27.76 rows=976 width=47) (actual time=0.469..0.469 rows=976 loops=1)',),
#  ('              Buckets: 1024  Batches: 1  Memory Usage: 83kB',),
#  ('              ->  Seq Scan on races  (cost=0.00..27.76 rows=976 width=47) (actual time=0.005..0.247 rows=976 loops=1)',),
#  ('  ->  Hash  (cost=2.73..2.73 rows=73 width=28) (actual time=0.040..0.040 rows=73 loops=1)',),
#  ('        Buckets: 1024  Batches: 1  Memory Usage: 13kB',),
#  ('        ->  Seq Scan on circuits  (cost=0.00..2.73 rows=73 width=28) (actual time=0.010..0.023 rows=73 loops=1)',),
#  ('Planning time: 0.515 ms',),
#  ('Execution time: 5.870 ms',)]

# %%
# %sql CREATE MATERIALIZED VIEW winners_cache AS SELECT * FROM winners;
# Out:
# 154 rows affected.
# []

# %%
# %sql EXPLAIN ANALYZE SELECT * FROM winners_cache;
# Out:
# 3 rows affected.
# [('Seq Scan on winners_cache  (cost=0.00..10.50 rows=50 width=1568) (actual time=0.010..0.028 rows=154 loops=1)',),
#  ('Planning time: 0.121 ms',),
#  ('Execution time: 0.047 ms',)]

# %% [markdown]
# A materialized view is a database object that contains the results of a query. For example, it may be a local copy of data located remotely, or may be a subset of the rows and/or columns of a table or join result, or may be a summary using an aggregate function. Basically, it is a snapshot (which was the actual name in prior releases) which replicates data. The data can not be update following that the execution time is reduced exponentially. The basic use of this would be with databases that are used generally for reading instead of writing.
